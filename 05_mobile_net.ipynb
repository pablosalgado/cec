# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# -----------------------------------------------------------------------------
# Trains a model based on MobileNet.
#
# author: Pablo Salgado
# contact: pabloasalgado@gmail.com
#
# https://unir-tfm-cec.s3.us-east-2.amazonaws.com/models/05/MobileNet.tar.gz

import os

import tensorflow as tf

import common
import generators

# Parameters
TIME_STEPS = 16
EPOCHS = 50
MDL_PATH = '/content/drive/My Drive/models/05/MobileNet'

os.makedirs(MDL_PATH, exist_ok=True)

CKP_PATH = MDL_PATH + '/ckpts/cp-{epoch:04d}.ckpt'
LOG_PATH = MDL_PATH + '/training.csv'
PLT_PATH = MDL_PATH + '/plot.png'
SVD_PATH = MDL_PATH + '/model'

# Configure callbacks
CALLBACKS = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=CKP_PATH,
        save_weights_only=True,
        verbose=1
    ),
    tf.keras.callbacks.CSVLogger(
        filename=LOG_PATH
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='loss',
        patience=2
    )
]


def build_model():
    # Load MobileNet model excluding top.
    pre_model = tf.keras.applications.mobilenet.MobileNet(
        include_top=False,
        input_shape=(224, 224, 3)
    )

    pre_model.summary()

    # Allows to retrain the last convolutional layer.
    for layer in pre_model.layers[:-3]:
        layer.trainable = False

    # Build the new CNN adding a layer to flatten the convolution as required
    # to 1D for the RNN.
    cnn_model = tf.keras.models.Sequential(
        [
            pre_model,
            tf.keras.layers.GlobalMaxPool2D()
        ]
    )

    # Now build the RNN model.
    rnn_model = tf.keras.models.Sequential()

    # Process n frames, each of 224x244x3
    rnn_model.add(tf.keras.layers.TimeDistributed(cnn_model, input_shape=(TIME_STEPS, 224, 224, 3)))

    # Build the classification layer.
    rnn_model.add(tf.keras.layers.LSTM(64))
    rnn_model.add(tf.keras.layers.Dense(1024, activation='relu'))
    rnn_model.add(tf.keras.layers.Dropout(0.5))
    rnn_model.add(tf.keras.layers.Dense(51, activation='softmax'))

    rnn_model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.sparse_categorical_crossentropy,
        metrics=['accuracy']
    )

    return rnn_model


def train():
    # Download and split data.
    common.split_data(TIME_STEPS)

    # Build and compile the model.
    model = build_model()

    # model.save_weights(CKP_PATH.format(epoch=0))

    # Load last checkpoint if any.
    # model.load_weights(
    #     tf.train.latest_checkpoint(
    #         os.path.dirname(CKP_PATH)
    #     )
    # )

    train_idg = generators.TimeDistributedImageDataGenerator(
        rotation_range=30,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        rescale=1. / 255,
        time_steps=TIME_STEPS,
    )

    validation_idg = generators.TimeDistributedImageDataGenerator(
        time_steps=TIME_STEPS,
    )

    history = model.fit(
        train_idg.flow_from_directory(
            common.TRAIN_DATA_PATH,
            target_size=(224, 224),
            batch_size=32,
            class_mode='sparse',
            shuffle=False,
            # classes=['agree_pure', 'agree_considered'],
            # save_to_dir='./data/train'
        ),
        validation_data=validation_idg.flow_from_directory(
            common.VALIDATION_DATA_PATH,
            target_size=(224, 224),
            batch_size=32,
            class_mode='sparse',
            shuffle=False,
            # classes=['agree_pure', 'agree_considered'],
            # save_to_dir='./data/test'
        ),
        callbacks=CALLBACKS,
        epochs=EPOCHS,
    )

    model.save(SVD_PATH)

    common.plot_acc_loss(history, PLT_PATH)


if __name__ == '__main__':
    train()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# Found 6528 images belonging to 51 classes.
# Found 816 images belonging to 51 classes.
# Epoch 1/50
# 204/204 [==============================] - ETA: 0s - loss: 4.0829 - accuracy: 0.0066
# Epoch 00001: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0001.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 4.0829 - accuracy: 0.0066 - val_loss: 3.9320 - val_accuracy: 0.0196
# Epoch 2/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0098
# Epoch 00002: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0002.ckpt
# 204/204 [==============================] - 330s 2s/step - loss: 3.9350 - accuracy: 0.0098 - val_loss: 3.9320 - val_accuracy: 0.0196
# Epoch 3/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0098
# Epoch 00003: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0003.ckpt
# 204/204 [==============================] - 328s 2s/step - loss: 3.9350 - accuracy: 0.0098 - val_loss: 3.9320 - val_accuracy: 0.0196
# Epoch 4/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9353 - accuracy: 0.0049
# Epoch 00004: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0004.ckpt
# 204/204 [==============================] - 328s 2s/step - loss: 3.9353 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 5/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0000e+00
# Epoch 00005: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0005.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9352 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 6/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00006: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0006.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 7/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0000e+00
# Epoch 00007: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0007.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9352 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 8/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9353 - accuracy: 0.0049
# Epoch 00008: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0008.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9353 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 9/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0098
# Epoch 00009: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0009.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9350 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 10/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0000e+00
# Epoch 00010: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0010.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 11/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0098
# Epoch 00011: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0011.ckpt
# 204/204 [==============================] - 329s 2s/step - loss: 3.9351 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 12/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00012: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0012.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 13/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0049
# Epoch 00013: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0013.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9352 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 14/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0049
# Epoch 00014: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0014.ckpt
# 204/204 [==============================] - 329s 2s/step - loss: 3.9352 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 15/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00015: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0015.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 16/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00016: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0016.ckpt
# 204/204 [==============================] - 323s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 17/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0098
# Epoch 00017: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0017.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9351 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 18/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00018: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0018.ckpt
# 204/204 [==============================] - 322s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 19/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00019: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0019.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 20/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00020: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0020.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 21/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0098
# Epoch 00021: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0021.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9352 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 22/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0147
# Epoch 00022: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0022.ckpt
# 204/204 [==============================] - 330s 2s/step - loss: 3.9350 - accuracy: 0.0147 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 23/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00023: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0023.ckpt
# 204/204 [==============================] - 329s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 24/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0000e+00
# Epoch 00024: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0024.ckpt
# 204/204 [==============================] - 329s 2s/step - loss: 3.9352 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 25/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9349 - accuracy: 0.0098
# Epoch 00025: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0025.ckpt
# 204/204 [==============================] - 328s 2s/step - loss: 3.9349 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 26/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00026: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0026.ckpt
# 204/204 [==============================] - 331s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 27/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00027: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0027.ckpt
# 204/204 [==============================] - 333s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 28/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00028: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0028.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 29/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0000e+00
# Epoch 00029: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0029.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 3.9351 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 30/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9349 - accuracy: 0.0049
# Epoch 00030: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0030.ckpt
# 204/204 [==============================] - 327s 2s/step - loss: 3.9349 - accuracy: 0.0049 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 31/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00031: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0031.ckpt
# 204/204 [==============================] - 323s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 32/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0098
# Epoch 00032: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0032.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9351 - accuracy: 0.0098 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 33/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0000e+00
# Epoch 00033: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0033.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9351 - accuracy: 0.0000e+00 - val_loss: 3.9319 - val_accuracy: 0.0196
# Epoch 34/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0049
# Epoch 00034: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0034.ckpt
# 204/204 [==============================] - 323s 2s/step - loss: 3.9352 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 35/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00035: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0035.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 36/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9349 - accuracy: 0.0098
# Epoch 00036: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0036.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9349 - accuracy: 0.0098 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 37/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0098
# Epoch 00037: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0037.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0098 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 38/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00038: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0038.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 39/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00039: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0039.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 40/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0049
# Epoch 00040: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0040.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9352 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 41/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00041: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0041.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 42/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0098
# Epoch 00042: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0042.ckpt
# 204/204 [==============================] - 322s 2s/step - loss: 3.9350 - accuracy: 0.0098 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 43/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00043: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0043.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 44/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0049
# Epoch 00044: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0044.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9350 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 45/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9350 - accuracy: 0.0000e+00
# Epoch 00045: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0045.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9350 - accuracy: 0.0000e+00 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 46/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00046: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0046.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 47/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00047: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0047.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 48/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0049
# Epoch 00048: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0048.ckpt
# 204/204 [==============================] - 326s 2s/step - loss: 3.9351 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 49/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9351 - accuracy: 0.0098
# Epoch 00049: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0049.ckpt
# 204/204 [==============================] - 325s 2s/step - loss: 3.9351 - accuracy: 0.0098 - val_loss: 3.9318 - val_accuracy: 0.0196
# Epoch 50/50
# 204/204 [==============================] - ETA: 0s - loss: 3.9352 - accuracy: 0.0049
# Epoch 00050: saving model to /content/drive/My Drive/models/1/MobileNet/ckpts/cp-0050.ckpt
# 204/204 [==============================] - 324s 2s/step - loss: 3.9352 - accuracy: 0.0049 - val_loss: 3.9318 - val_accuracy: 0.0196
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/models/1/MobileNet/model/assets
